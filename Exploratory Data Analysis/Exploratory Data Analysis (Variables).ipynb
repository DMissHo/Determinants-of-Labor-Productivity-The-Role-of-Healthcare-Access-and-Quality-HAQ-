# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('C:\\Users\\user\\Desktop\\Data Cleaning\\Data.xlsx')

# %%
df.head()
# Out:
#      Country  Year  Labor Productivity        HAQ  \
# 0  Argentina  2000           23.287077  76.100000
# 1  Argentina  2005           21.956108  77.200000
# 2  Argentina  2010           27.548946  79.600000
# 3  Argentina  2015           30.041763  81.900000
# 4  Argentina  2019           33.711970  59.876111
#
#    Government expenditure on education, total (% of GDP: Constant 2015)  \
# 0                                           3.290166
# 1                                           1.762309
# 2                                           3.847187
# 3                                           5.776110
# 4                                           3.738780
#
#    Control of Corruption: Estimate  \
# 0                        -0.172408
# 1                        -0.377738
# 2                        -0.355230
# 3                        -0.581265
# 4                        -0.107116
#
#    Individuals using the Internet (% of population)  \
# ...

# %%
corr_matrix =  df.corr()
print(corr_matrix)
# Out:
#                                                         Year  \
# Year                                                1.000000
# Labor Productivity                                  0.204323
# HAQ                                                -0.074854
# Government expenditure on education, total (% o...  0.408586
# Control of Corruption: Estimate                    -0.032049
# Individuals using the Internet (% of population)    0.682707
# FDI (US$ at current prices in millions)             0.061209
#
#                                                     Labor Productivity  \
# Year                                                          0.204323
# Labor Productivity                                            1.000000
# HAQ                                                           0.701393
# Government expenditure on education, total (% o...            0.554087
# Control of Corruption: Estimate                               0.818138
# ...

# %%
plt.figure(figsize=(8,6))
sns.heatmap(corr_matrix,  annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title("Corrlation Heatmap of Labor Productivity & Others Variables")
plt.savefig("corr.png", dpi=300, bbox_inches='tight')
plt.show()

# %%
# Listing of independent variables
independent_vars = ['HAQ','Government expenditure on education, total (% of GDP: Constant 2015)',
                    'Control of Corruption: Estimate','Individuals using the Internet (% of population)',
                    'FDI (US$ at current prices in millions)']
 
# Creating subplots
fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(15, 15)) 
fig.suptitle("Labor Productivity vs. Various Factors", fontsize=16)
 
# Flatten axes for easy iteration
axes = axes.flatten()
 
# Loop through variables and create subplots
for i, var in enumerate(independent_vars):
    sns.regplot(data=df, x=var, y='Labor Productivity', ax=axes[i])
    axes[i].set_title(f"Labor Productivity vs. {var}")

plt.tight_layout(rect=[0, 0, 1, 0.96])  # Adjust layout to fit title
plt.savefig("labor.png", dpi=300, bbox_inches='tight')
plt.show()

# %%
df.hist(bins=20,figsize=(12,12))
plt.suptitle("Histogram of Features", y=1.02)
plt.tight_layout()
plt.show()
